# %%
########################## 这个是最终的结果，之前的相关性写错了 ##############
#关于文档的一个数据分类
import pandas as pd
import seaborn as sns  #用于绘制热图的工具包
from scipy.cluster import hierarchy  #用于进行层次聚类，话层次聚类图的工具包
from scipy import cluster   
import matplotlib.pyplot as plt
from sklearn import decomposition as skldec #用于主成分分析降维的包
import numpy as np
#import csv
import math
from pandas import Series,DataFrame
from matplotlib.ticker import  MultipleLocator
import pylab as pl   #画图用
from sklearn import svm
from sklearn import linear_model

# %%
pop=['2000Pop','2001Pop','2002Pop','2003Pop','2004Pop','2005Pop','2006Pop','2007Pop','2008Pop','2009Pop',
     '2010Pop','2011Pop','2012Pop','2013Pop','2014Pop','2015Pop','2016Pop','2017Pop']
gdp=['2000GDP','2001GDP','2002GDP','2003GDP','2004GDP','2005GDP','2006GDP','2007GDP','2008GDP','2009GDP',
     '2010GDP','2011GDP','2012GDP','2013GDP','2014GDP','2015GDP','2016GDP','2017GDP']
area=['2000Area','2001Area','2002Area','2003Area','2004Area','2005Area','2006Area','2007Area','2008Area','2009Area',
     '2010Area','2011Area','2012Area','2013Area','2014Area','2015Area','2016Area','2017Area']
roadleng=['2000Roadleng','2001Roadleng','2002Roadleng','2003Roadleng','2004Roadleng','2005Roadleng','2006Roadleng','2007Roadleng','2008Roadleng','2009Roadleng',
     '2010Roadleng','2011Roadleng','2012Roadleng','2013Roadleng','2014Roadleng','2015Roadleng','2016Roadleng','2017Roadleng']
inv_times=['2000invtime','2001invtime','2002invtime','2003invtime','2004invtime','2005invtime','2006invtime','2007invtime','2008invtime','2009invtime',
     '2010invtime','2011invtime','2012invtime','2013invtime','2014invtime','2015invtime','2016invtime','2017invtime']
investment=['2000inv','2001inv','2002inv','2003inv','2004inv','2005inv','2006inv','2007inv','2008inv','2009inv',
     '2010inv','2011inv','2012inv','2013inv','2014inv','2015inv','2016inv','2017inv']

# %%
data =pd.read_excel('E:/文档系列/python 系列/TheData/0_theDATA_end(1991-2017pop&GDP&vc)/ALL_Intersection(1991-2017仅插值).xlsx')  # 读取训练数据
city=data['City'].drop_duplicates().values
City=data['city'].drop_duplicates().values

# %%
from scipy.optimize import leastsq  ##引入最小二乘法算法
#需要拟合的函数func :指定函数的形状
def func(p,x):
    k,b=p
    return k*x+b

##偏差函数：x,y都是列表:这里的x,y更上面的Xi,Yi中是一一对应的
def error(p,x,y):
    return func(p,x)-y

plt.rcParams['font.sans-serif']=['Simhei']     #解决中文显示问题，目前只知道黑体可行
plt.rcParams['axes.unicode_minus']=False       #解决负数坐标显示问题

# %%
##### 求残差 logy-log（kx+b）
def GuiJI(data,xl,yl,i,xname,yname):
    ###xl,yl：列名的list,xname,yname：列名,i:年份
    city=data['City'].drop_duplicates().values
    province=data['province'].values###得到省
    r=[]  ###标度率
    ###保存取完log后大于0的值
    p=[]
    g=[]
    ###保存所有的log值，小于0的记录为-1
    p2=[]
    g2=[]
    ###取列值的log
    XI=data[xl[i]]
    YI=data[yl[i]]
    xi=np.log(XI)
    yi=np.log(YI)
    XII=xi.fillna(np.infty) ###将空值置为inf
    YII=yi.fillna(np.infty)
    ###判断是否大于0
    City=[]###保存log值大于0的城市名
    pro=[]###保存log值大于0的省名
    for mm in range(len(XII)):
        if XII[mm]==-float('Inf') or XII[mm]==float('Inf') or YII[mm]==-float('Inf') or YII[mm]==float('Inf'):
            continue
        else:
            p.append(XII[mm])
            g.append(YII[mm])
#             p2.append(XII[mm])
#             g2.append(YII[mm])
            City.append(city[mm])
            pro.append(province[mm])
                           
    #k,b的初始值，可以任意设定,经过几次试验，发现p0的值会影响cost的值：Para[1]
    p0=[1,10]
    Xi=np.array(p)
    Yi=np.array(g)
    #把error函数中除了p0以外的参数打包到args中(使用要求)
    Para=leastsq(error,p0,args=(Xi,Yi))## 三个参数：误差函数、函数参数列表、数据点
    #读取结果
    k,b=Para[0]
    ###将标度率写入r中
    r.append(k) 
    y = [k*x+b for x in p]
    ###得到残差
    sc=[g[v]-y[v] for v in range(len(g))]
    
    ###计算频率分布
    maxsc=max(sc)
    minsc=min(sc)
    Paragraph_len=(maxsc-minsc)/10
    fresc=[]###频率
    xvalue=[] ###坐标所在数段
    for i in range(10):###划分成10个段
        num=0
        psc=minsc+Paragraph_len*i ###左坐标
        rpsc=psc+Paragraph_len    ###右坐标
        for scj in sc:
            if scj>=psc and scj<rpsc:
                num=num+1
        fresc.append(num/len(City))
        xvalue.append((psc+rpsc)/2)
        
    ###按照sc的值进行排序
    scdic = list(zip(sc,City))
    scSort = sorted( scdic)###残差城市排序
    
#     prodic = dict(zip(pro,sc))
#     proSort = sorted( prodic.items(),key = lambda x:x[1],reverse = True)###省作为item会有很多省北过滤掉
    prodic = list(zip(sc,pro))
    proSort = sorted( prodic)
    return(r,City,p,g,y,sc,fresc,xvalue,scSort,k,b,proSort)

# %%
###让颜色匹配
Name_M=[1,2,3,4]
yj_color = {'1':(0.7247999999999999, 0.86, 0.33999999999999997),'2':(0.86, 0.3712, 0.33999999999999997),'3':'#FF9933','4':(0.33999999999999997, 0.5167999999999995, 0.86)}
vv = np.arange(1,27)
a=list(sns.color_palette("hls", 26))
yj_color2={'1':(0.86, 0.3712, 0.33999999999999997),'2':'#FF9933','3':a[15]}###让times显示不同的颜色
# yj_color = {'1':(0.86, 0.3712, 0.33999999999999997),'2':(0.7247999999999999, 0.86, 0.33999999999999997),'3':'#FF9933','4':(0.33999999999999997, 0.5167999999999995, 0.86)}

# %%
#################关于GDP的复现##########

# %%
def getCity(s):
    a=list(s.split('|'))
    return(a[0])
data['province']=data.city.map(getCity)
province=data['province'].drop_duplicates().values###得到省
c=len(province)###一级产业数量
a=list(sns.color_palette("hls", c))
# yj_color=dict(zip(province,a))

# %%
###热图
###每一个城市的残差的均值
### 相关性应该是 平方和开方为分母，连×之和为分子
def get_cij(scall,cityname):
    dfscyear = pd.DataFrame(scall, columns=cityname)###将每一年的残差转化为dataframe city*year
    ###求Cij
    Cij=[]
    for i in range(len(cityname)):
        c1=dfscyear[cityname[i]].values###得到城市1的残差
        c1Sum = 0
        for ccc in range(18):
            c1Sum += c1[ccc]**2 ###城市17年间残差平方连加
        lenc1 = math.sqrt(c1Sum)###得到分母
        #absc1=cityAvg[i]
        cij=[]
        for j in range(len(cityname)):
            c2=dfscyear[cityname[j]].values###得到城市2的残差
            addc12=0
            c2Sum = 0
            for c in range(18):
                mul=c1[c]*c2[c]
                addc12=addc12+mul
                c2Sum += c2[c]**2 ###城市17年间残差平方连加
            lenc2 = math.sqrt(c2Sum)###得到分母
            c12=addc12/(lenc1*lenc2)
            cij.append(c12)###两个城市cij
        Cij.append(cij)
    dfCij= pd.DataFrame(Cij)  
    return(dfCij)

# %%
########## 
cityM = GuiJI(data,pop,investment,15,'pop','amount')[1]###按照2015年含有投资金额的城市来删选2000-2016年间关于GDP\amount\times的数据
####查看一些城市2000-2016年的残差分布图
scall=[]###保存所有城市2000-2016年的残差
scallM=[]
scallT=[]
for i in range(18):    
    ### GDP残差
    sami=GuiJI(data,pop,gdp,i,'pop','GDP')
    sc=sami[5]###获取某一年的残差值
    cityname=sami[1]###城市名

    ###amount
    samiM=GuiJI(data,pop,investment,i,'pop','amount')
    scM=samiM[5]###获取某一年的残差值
    citynameM=samiM[1]###城市名

    ###times
    samiT=GuiJI(data,pop,inv_times,i,'pop','times')
    scT=samiT[5]###获取某一年的残差值
    citynameT=samiT[1]###城市名
 
    ### 删选出来含有投资的城市的GDP\TIMES
    sc_GDP0=[] ###保存含有投资的城市的GDP
    sc_amount0 = [] ###投资金额
    sc_times0=[] ###保存旱藕投资的城市的投资次数
    
    ### 1 得到GDP的数据
    for c1 in cityM:
        have = 0 ###标值该城市是否存在,0表示不存在
        for c2 in range(len(cityname)):
            if cityname[c2] == c1:
                sc_GDP0.append(sc[c2])
                have = 1
        if have == 0:
            sc_GDP0.append(0)
    ### 2 得到投资金额的数据
    for c1 in cityM:
        have1 = 0 ###标值该城市是否存在,0表示不存在
        for c2 in range(len(citynameM)):
            if citynameM[c2] == c1:
                sc_amount0.append(scM[c2])
                have1 = 1
        if have1 == 0:
            sc_amount0.append(0)
    ### 3 得到投资次数的残差数据
    for c1 in cityM:
        have2 = 0
        for c2 in range(len(citynameT)):
            if citynameT[c2] == c1:
                sc_times0.append(scT[c2])
                have2 = 1
        if have2 == 0:
            sc_times0.append(0)
            
    scallM.append(sc_amount0)###得到删选后的残差,城市和投资金额城市保持一致
    scallT.append(sc_times0)
    scall.append(sc_GDP0)
# Out:
# D:\Users\lu\Anaconda3\lib\site-packages\ipykernel_launcher.py:17: RuntimeWarning: divide by zero encountered in log

# %%
len(scallM[0]),len(scallT[0]),len(scall[0])
# Out:
# (149, 149, 149)

# %%
################ 得到相关性矩阵
dfAmount = get_cij(scallM,cityM)
dfTimes = get_cij(scallT,cityM)
dfGDP = get_cij(scall,cityM)

# %%
from scipy.cluster.hierarchy import cophenet
from scipy.spatial.distance import pdist
import matplotlib.pyplot as plt
from scipy.cluster.hierarchy import dendrogram, linkage
# %matplotlib inline

# %%
##################### 1 得到投资金额的相关性给聚类结果和热图 #################

# %%
ptd=(1-dfAmount)/2
np.set_printoptions(precision=5, suppress=True)  # suppress scientific float notation
Z11 = linkage(ptd, 'ward')
end = 20
last = Z11[0:, 2]#Z的第三列
last_rev = last[::-1]#Z倒过来读
idxs = np.arange(1, len(last) + 1)
plt.plot(idxs[:end], last_rev[:end])

# %%
###2.3
from scipy.cluster.hierarchy import fcluster
#max_d = 10#切割线
#clusters1 = fcluster(Z11, max_d, criterion='distance')
#1:北京市2：上海市4:广东省深圳市,广东省珠海市,浙江省杭州市,江苏省苏州市
clusters_M = fcluster(Z11,4, criterion='maxclust')
plt.hist(clusters_M,bins=4)
#clusters2_1
# Out:
# (array([68., 40., 15., 26.]),
#  array([1.  , 1.75, 2.5 , 3.25, 4.  ]),
#  <a list of 4 Patch objects>)

# %%
clusters_M
# Out:
# array([1, 1, 4, 4, 2, 4, 2, 2, 3, 1, 1, 4, 1, 3, 4, 2, 2, 4, 4, 1, 2, 4,
#        2, 1, 2, 1, 2, 2, 1, 3, 1, 1, 1, 2, 1, 1, 1, 3, 2, 2, 1, 1, 1, 3,
#        1, 1, 4, 1, 1, 1, 1, 3, 2, 3, 1, 1, 1, 1, 3, 2, 1, 1, 1, 2, 1, 1,
#        1, 1, 4, 4, 4, 1, 4, 1, 1, 1, 1, 1, 1, 2, 2, 1, 1, 2, 2, 4, 4, 2,
#        3, 2, 4, 2, 2, 4, 4, 1, 4, 2, 1, 2, 1, 1, 2, 1, 2, 4, 1, 1, 2, 2,
#        4, 2, 1, 2, 1, 1, 3, 1, 1, 4, 1, 4, 1, 3, 2, 2, 1, 4, 2, 3, 2, 1,
#        3, 2, 3, 2, 1, 1, 1, 4, 1, 4, 1, 1, 1, 3, 1, 2, 2], dtype=int32)

# %%
print('1:',cityM[:68])
print('2:',cityM[68:68+40])
print('3:',cityM[68+40:68+40+15])
print('4:',cityM[68+40+15:])
# Out:
# 1: ['北京', '天津', '石家庄', '唐山', '秦皇岛', '邯郸', '邢台', '保定', '承德', '沧州', '廊坊', '太原', '吕梁', '呼和浩特', '包头', '沈阳', '大连', '本溪', '营口', '铁岭', '朝阳', '葫芦岛', '长春', '吉林', '通化', '白山', '哈尔滨', '大庆', '黑河', '绥化', '上海', '南京', '无锡', '徐州', '常州', '苏州', '南通', '连云港', '淮安', '盐城', '扬州', '镇江', '泰州', '宿迁', '杭州', '宁波', '温州', '嘉兴', '湖州', '绍兴', '金华', '衢州', '舟山', '台州', '合肥', '芜湖', '蚌埠', '马鞍山', '铜陵', '安庆', '宣城', '福州', '厦门', '莆田', '泉州', '漳州', '南平', '龙岩']
# 2: ['南昌', '萍乡', '九江', '新余', '赣州', '吉安', '宜春', '抚州', '上饶', '济南', '青岛', '淄博', '东营', '烟台', '潍坊', '济宁', '威海', '日照', '莱芜', '临沂', '德州', '滨州', '郑州', '开封', '洛阳', '平顶山', '安阳', '新乡', '焦作', '濮阳', '许昌', '商丘', '驻马店', '武汉', '宜昌', '荆门', '孝感', '荆州', '黄冈', '长沙']
# 3: ['株洲', '湘潭', '衡阳', '常德', '益阳', '永州', '怀化', '广州', '韶关', '深圳', '珠海', '汕头', '佛山', '江门', '肇庆']
# 4: ['惠州', '河源', '东莞', '中山', '南宁', '柳州', '海口', '重庆', '成都', '自贡', '绵阳', '乐山', '昆明', '玉溪', '西安', '咸阳', '汉中', '榆林', '兰州', '白银', '定西', '西宁', '银川', '吴忠', '乌鲁木齐', '克拉玛依']

# %%
cludfM=pd.DataFrame()###保存城市和分类在dataframe,并将每一类分类对应不同颜色
cludfM['city']=cityM
cludfM['cluster']=clusters_M
yjNameM=cludfM['cluster'].drop_duplicates().values###得到聚类类别
cM=len(yjNameM)###一级产业数量
aM=list(sns.color_palette("hls", cM))
yj_colorM=dict(zip(yjNameM,aM))

# %%
dfCijM=dfAmount
dfCijM['cluster']=clusters_M
clusterm=sorted(dfCijM['cluster'].drop_duplicates().values)
DATA=[]###按照城市对数据进行分组
s=[]
for li in clusterm:
    dat=dfCijM[dfCijM['cluster'].isin([li])]
    DATA.append(dat)
    s.append(dat.shape[0])

# %%
len(DATA[0])
# Out:
# 68

# %%
dataM1=DATA[0].append(DATA[1])
dataM2=DATA[2].append(DATA[3])
# dataM3=dataM2.append(DATA[4])
dataM=dataM1.append(dataM2)
dataM_2 = dataM.drop(['cluster'], axis=1)##去除cluster列数据

# %%
### 按照列对相关性数据进行排序，先将dataframe转置，再按照行进行排序即可
dataM_3 = dataM_2.T ###转置
dataM_3['cluster']=clusters_M
# clusterm=dfCijM['cluster'].drop_duplicates().values
DATA_col_M = []###按照城市对数据进行分组
s_col_M = []
for li in clusterm:
    dat_col_M = dataM_3[dataM_3['cluster'].isin([li])]
    DATA_col_M.append(dat_col_M)
    s_col_M.append(dat_col_M.shape[0])
    
### 按照得到的分类数据进行排序
dataN1_col_M=DATA_col_M[0].append(DATA_col_M[1])
dataN2_col_M=DATA_col_M[2].append(DATA_col_M[3])
# dataN3_col_M=dataN2_col_M.append(DATA_col_M[4])
dataN_col_M=dataN1_col_M.append(dataN2_col_M)

# %%
### 画出热图 
# Dff=dff[dff<0.1]
# DFF= Dff[dff>0.016]
# DFF2=np.log10(DFF)
##### 得到先惯性的热图 ##########
DFF2 = dataN_col_M.drop(['cluster'], axis=1) ###将cluster列删除
# l1=len(dataA1)
# l2=l1+len(dataA2)
# l3=l2+len(dataA3)
# l4=l3+len(dataA4)
# l5=l4+len(dataA5)
l1 = s_col_M[0]
l2 = s_col_M[1]+l1
l3 = s_col_M[2]+l2
l4 = s_col_M[3]+l3
l5 = s_col_M[3]


f,ax1M = plt.subplots(figsize = (9,7))
cmap = plt.cm.get_cmap('seismic')
sns.heatmap(DFF2, linewidths = 0.05, ax = ax1M, vmax=max(DFF2.max().values), vmin=min(DFF2.min().values), xticklabels=False, yticklabels=False, cmap=cmap,cbar =False)
# plt.axhline(y=l1,linestyle="-",color="black")#添加垂直直线
plt.axvline(x=0,linestyle="-",color="black",linewidth=1)#添加垂直直线
plt.axhline(y=0,linestyle="-",color="black",linewidth=1)#添加垂直直线
plt.vlines(x=l1,linestyle="-",ymin=0,ymax=l1,color=yj_color['1'],linewidth=5)#添加垂直直线,#线起始位置
plt.vlines(x=l1,linestyle="-",ymin=l1,ymax=l2,color=yj_color['2'],linewidth=5)#添加垂直直线,#线起始位置
# plt.axvline(x=l4,linestyle="-",color="black",linewidth=1)#添加垂直直线
# plt.axhline(y=l4,linestyle="-",color="black",linewidth=1)#添加垂直直线
# plt.axhline(y=l2,linestyle="-",color="black")#添加垂直直线
plt.vlines(x=l2,linestyle="-",ymin=l1,ymax=l2,color=yj_color['2'],linewidth=5)#添加垂直直线
plt.vlines(x=l2,linestyle="-",ymin=l2,ymax=l3,color=yj_color['3'],linewidth=5)#添加垂直直线
plt.vlines(x=l3,linestyle="-",ymin=l2,ymax=l3,color=yj_color['3'],linewidth=5)#添加垂直直线
plt.vlines(x=l3,linestyle="-",ymin=l3,ymax=l4,color=yj_color['4'],linewidth=5)#添加垂直直线

plt.plot(np.arange(0,l1+1),[l1 for xx in range(l1+1)],color=yj_color['1'],linewidth=5)###1
plt.plot(np.arange(l1,l2+1),[l1 for xx in range(l1,l2+1)],color=yj_color['2'],linewidth=5)
plt.plot(np.arange(l1,l2+1),[l2 for xx in range(l1,l2+1)],color=yj_color['2'],linewidth=5)###3
plt.plot(np.arange(l2,l3+1),[l2 for xx in range(l2,l3+1)],color=yj_color['3'],linewidth=5)###2
plt.plot(np.arange(l2,l3+1),[l3 for xx in range(l2,l3+1)],color=yj_color['3'],linewidth=5)###4
plt.plot(np.arange(l3,l4+1),[l3 for xx in range(l3,l4+1)],color=yj_color['4'],linewidth=5)

plt.plot(np.arange(0,l4),[l4-0.5 for xx in range(l4)],color="black",linewidth=1)
plt.plot([l4-0.3 for xx in range(l4)],np.arange(0,l4),color="black",linewidth=1)


# plt.axhline(y=l1,xmin=1,xmax=3,color="black",linestyle='-')#线型
# plt.savefig('C:\\Users\\lu\\Desktop\\标度律\\4_retu.png')#保存图片
# plt.tight_layout()
plt.savefig('E:/文档系列/python 系列/picScalling/20201025NEW/Fig3_d_amount.pdf', bbox_inches='tight')

# %%
######### 2 得到投资次数的热图

# %%
ptd=(1-dfTimes)/2
np.set_printoptions(precision=5, suppress=True)  # suppress scientific float notation
Z11_T = linkage(ptd, 'ward')
end = 20
last = Z11_T[0:, 2]#Z的第三列
last_revT = last[::-1]#Z倒过来读
idxsT = np.arange(1, len(last) + 1)
plt.plot(idxsT[:end], last_revT[:end])

# %%
###2.3
from scipy.cluster.hierarchy import fcluster
#max_d = 10#切割线
#clusters1 = fcluster(Z11, max_d, criterion='distance')
#1:北京市2：上海市4:广东省深圳市,广东省珠海市,浙江省杭州市,江苏省苏州市
clusters_T = fcluster(Z11_T,4, criterion='maxclust')
plt.hist(clusters_T,bins=4)
#clusters2_1
# Out:
# (array([62., 35., 13., 39.]),
#  array([1.  , 1.75, 2.5 , 3.25, 4.  ]),
#  <a list of 4 Patch objects>)

# %%
print('1:',cityM[:62])
print('2:',cityM[62:62+35])
print('3:',cityM[62+35:62+35+13])
print('4:',cityM[62+35+13:])
# Out:
# 1: ['北京', '天津', '石家庄', '唐山', '秦皇岛', '邯郸', '邢台', '保定', '承德', '沧州', '廊坊', '太原', '吕梁', '呼和浩特', '包头', '沈阳', '大连', '本溪', '营口', '铁岭', '朝阳', '葫芦岛', '长春', '吉林', '通化', '白山', '哈尔滨', '大庆', '黑河', '绥化', '上海', '南京', '无锡', '徐州', '常州', '苏州', '南通', '连云港', '淮安', '盐城', '扬州', '镇江', '泰州', '宿迁', '杭州', '宁波', '温州', '嘉兴', '湖州', '绍兴', '金华', '衢州', '舟山', '台州', '合肥', '芜湖', '蚌埠', '马鞍山', '铜陵', '安庆', '宣城', '福州']
# 2: ['厦门', '莆田', '泉州', '漳州', '南平', '龙岩', '南昌', '萍乡', '九江', '新余', '赣州', '吉安', '宜春', '抚州', '上饶', '济南', '青岛', '淄博', '东营', '烟台', '潍坊', '济宁', '威海', '日照', '莱芜', '临沂', '德州', '滨州', '郑州', '开封', '洛阳', '平顶山', '安阳', '新乡', '焦作']
# 3: ['濮阳', '许昌', '商丘', '驻马店', '武汉', '宜昌', '荆门', '孝感', '荆州', '黄冈', '长沙', '株洲', '湘潭']
# 4: ['衡阳', '常德', '益阳', '永州', '怀化', '广州', '韶关', '深圳', '珠海', '汕头', '佛山', '江门', '肇庆', '惠州', '河源', '东莞', '中山', '南宁', '柳州', '海口', '重庆', '成都', '自贡', '绵阳', '乐山', '昆明', '玉溪', '西安', '咸阳', '汉中', '榆林', '兰州', '白银', '定西', '西宁', '银川', '吴忠', '乌鲁木齐', '克拉玛依']

# %%
dfCijT=dfTimes
dfCijT['cluster']=clusters_T
clusterT=sorted(dfCijT['cluster'].drop_duplicates().values)
aT=list(sns.color_palette("hls", len(clusterT)))
yj_colorT=dict(zip(clusterT,aT)) ####将颜色和类别匹配
DATAT=[]###按照城市对数据进行分组
sT=[]
for li in clusterT:
    dat=dfCijT[dfCijT['cluster'].isin([li])]
    DATAT.append(dat)
    sT.append(dat.shape[0])

# %%
dataT1=DATAT[0].append(DATAT[1])
dataT2=DATAT[2].append(DATAT[3])
# dataM3=dataM2.append(DATA[4])
dataT=dataT1.append(dataT2)
dataT_2 = dataT.drop(['cluster'], axis=1)##去除cluster列数据

# %%
### 按照列对相关性数据进行排序，先将dataframe转置，再按照行进行排序即可
dataT_3 = dataT_2.T ###转置
dataT_3['cluster']=clusters_T
# clusterm=dfCijM['cluster'].drop_duplicates().values
DATA_col_T = []###按照城市对数据进行分组
s_col_T = []
for li in clusterT:
    dat_col_T = dataT_3[dataT_3['cluster'].isin([li])]
    DATA_col_T.append(dat_col_T)
    s_col_T.append(dat_col_T.shape[0])
    
### 按照得到的分类数据进行排序
dataN1_col_T=DATA_col_T[0].append(DATA_col_T[1])
dataN2_col_T=DATA_col_T[2].append(DATA_col_T[3])
# dataN3_col_M=dataN2_col_M.append(DATA_col_M[4])
dataN_col_T=dataN1_col_T.append(dataN2_col_T)

# %%
### 画出热图 
##### 得到先惯性的热图 ##########
DFF2T = dataN_col_T.drop(['cluster'], axis=1) ###将cluster列删除
l1T = s_col_T[0]
l2T = s_col_T[1]+l1T
l3T = s_col_T[2]+l2T
l4T = s_col_T[3]+l3T
l5T = s_col_T[3]

f,ax1T = plt.subplots(figsize = (9,7))
cmap = plt.cm.get_cmap('seismic')
sns.heatmap(DFF2T, linewidths = 0.05, ax = ax1T, vmax=max(DFF2T.max().values), vmin=min(DFF2T.min().values), xticklabels=False, yticklabels=False, cmap=cmap,cbar =False)

plt.axvline(x=0,linestyle="-",color="black",linewidth=1)#添加垂直直线
plt.axhline(y=0,linestyle="-",color="black",linewidth=1)#添加垂直直线
plt.axvline(x=l4T,linestyle="-",color="black",linewidth=1)#添加垂直直线
plt.axhline(y=l4T,linestyle="-",color="black",linewidth=1)#添加垂直直线
# plt.plot(np.arange(0,l2T+1),[l1T for xx in range(l2T+1)],color="black",linewidth=3)
# plt.plot(np.arange(l1T,l3T+1),[l2T for xx in range(l1T,l3T+1)],color="black",linewidth=3)
# plt.plot(np.arange(l2T,l4T+1),[l3T for xx in range(l2T,l4T+1)],color="black",linewidth=3)
plt.plot(np.arange(0,l4T+1),[l4T-0.1 for xx in range(0,l4T+1)],color="black",linewidth=1)
plt.plot([l4T-0.1 for xx in range(0,l4T+1)],np.arange(0,l4T+1),color="black",linewidth=1)

plt.vlines(x=l1T,linestyle="-",ymin=0,ymax=l1T,color=yj_color['1'],linewidth=5)#添加垂直直线,#线起始位置
plt.vlines(x=l1T,linestyle="-",ymin=l1T,ymax=l2T,color=yj_color['2'],linewidth=5)#添加垂直直线,#线起始位置
plt.vlines(x=l2T,linestyle="-",ymin=l1T,ymax=l2T,color=yj_color['2'],linewidth=5)#添加垂直直线
plt.vlines(x=l2T,linestyle="-",ymin=l2T,ymax=l3T,color=yj_color['3'],linewidth=5)#添加垂直直线
plt.vlines(x=l3T,linestyle="-",ymin=l2T,ymax=l3T,color=yj_color['3'],linewidth=5)#添加垂直直线
plt.vlines(x=l3T,linestyle="-",ymin=l3T,ymax=l4T,color=yj_color['4'],linewidth=5)#添加垂直直线

plt.plot(np.arange(0,l1T+1),[l1T for xx in range(l1T+1)],color=yj_color['1'],linewidth=5)###1
plt.plot(np.arange(l1T,l2T+1),[l1T for xx in range(l1T,l2T+1)],color=yj_color['2'],linewidth=5)
plt.plot(np.arange(l1T,l2T+1),[l2T for xx in range(l1T,l2T+1)],color=yj_color['2'],linewidth=5)###3
plt.plot(np.arange(l2T,l3T+1),[l2T for xx in range(l2T,l3T+1)],color=yj_color['3'],linewidth=5)###2
plt.plot(np.arange(l2T,l3T+1),[l3T for xx in range(l2T,l3T+1)],color=yj_color['3'],linewidth=5)###4
plt.plot(np.arange(l3T,l4T+1),[l3T for xx in range(l3T,l4T+1)],color=yj_color['4'],linewidth=5)

plt.plot(np.arange(0,l4T+1),[l4T-0.5 for xx in range(0,l4T+1)],color="black",linewidth=1)
plt.plot([l4-0.5 for xx in range(0,l4T+1)],np.arange(0,l4T+1),color="black",linewidth=1)
# plt.axhline(y=l1,xmin=1,xmax=3,color="black",linestyle='-')#线型
# plt.savefig('C:\\Users\\lu\\Desktop\\标度律\\4_retuTimes.png')#保存图片
# plt.tight_layout()
plt.savefig('E:/文档系列/python 系列/picScalling/20201025NEW/Fig3_e_times.pdf', bbox_inches='tight')

# %%
####### times 分为三类 ###########

# %%
###2.3
from scipy.cluster.hierarchy import fcluster
#max_d = 10#切割线
#clusters1 = fcluster(Z11, max_d, criterion='distance')
#1:北京市2：上海市4:广东省深圳市,广东省珠海市,浙江省杭州市,江苏省苏州市
clusters_T2 = fcluster(Z11_T,3, criterion='maxclust')
plt.hist(clusters_T2,bins=3)
#clusters2_1
# Out:
# (array([62., 35., 52.]),
#  array([1.     , 1.66667, 2.33333, 3.     ]),
#  <a list of 3 Patch objects>)

# %%
dfCijT2=dfTimes
dfCijT2['cluster']=clusters_T2
clusterT2=sorted(dfCijT2['cluster'].drop_duplicates().values)
aT2=list(sns.color_palette("hls", len(clusterT2)))
yj_colorT2=dict(zip(clusterT2,aT2)) ####将颜色和类别匹配
DATAT2=[]###按照城市对数据进行分组
sT2=[]
for li in clusterT2:
    dat=dfCijT2[dfCijT2['cluster'].isin([li])]
    DATAT2.append(dat)
    sT2.append(dat.shape[0])
    
dataT12=DATAT2[0].append(DATAT2[1])
# dataT2=DATAT[2].append(DATAT[3])
# dataM3=dataM2.append(DATA[4])
dataT2=dataT12.append(DATAT2[2])
dataT2_2 = dataT2.drop(['cluster'], axis=1)##去除cluster列数据

### 按照列对相关性数据进行排序，先将dataframe转置，再按照行进行排序即可
dataT_32 = dataT2_2.T ###转置
dataT_32['cluster']=clusters_T2
# clusterm=dfCijM['cluster'].drop_duplicates().values
DATA_col_T2 = []###按照城市对数据进行分组
s_col_T2 = []
for li in clusterT2:
    dat_col_T2 = dataT_32[dataT_32['cluster'].isin([li])]
    DATA_col_T2.append(dat_col_T2)
    s_col_T2.append(dat_col_T2.shape[0])
    
### 按照得到的分类数据进行排序
dataN1_col_T2=DATA_col_T2[0].append(DATA_col_T2[1])
# dataN2_col_T2=DATA_col_T2[2].append(DATA_col_T2[3])
# dataN3_col_M=dataN2_col_M.append(DATA_col_M[4])
dataN_col_T2=dataN1_col_T2.append(DATA_col_T2[2])

# %%
### 画出热图 
##### 得到先惯性的热图 ##########
DFF2T2 = dataN_col_T2.drop(['cluster'], axis=1) ###将cluster列删除
l1T = s_col_T2[0]
l2T = s_col_T2[1]+l1T
l3T = s_col_T2[2]+l2T
# l4T = s_col_T[3]+l3T
# l5T = s_col_T[3]

f,ax1T2= plt.subplots(figsize = (8,7))
cmap = plt.cm.get_cmap('seismic')
sns.heatmap(DFF2T2, linewidths = 0.05, ax = ax1T2, vmax=max(DFF2T2.max().values), vmin=min(DFF2T2.min().values), xticklabels=False, yticklabels=False, cmap=cmap,cbar =False)

plt.axvline(x=0,linestyle="-",color="black",linewidth=1)#添加垂直直线
plt.axhline(y=0,linestyle="-",color="black",linewidth=1)#添加垂直直线
# plt.axvline(x=l3T,linestyle="-",color="black",linewidth=1)#添加垂直直线
# plt.axhline(y=l3T,linestyle="-",color="black",linewidth=1)#添加垂直直线
# plt.plot(np.arange(0,l2T+1),[l1T for xx in range(l2T+1)],color="black",linewidth=3)
# plt.plot(np.arange(l1T,l3T+1),[l2T for xx in range(l1T,l3T+1)],color="black",linewidth=3)
# plt.plot(np.arange(l2T,l4T+1),[l3T for xx in range(l2T,l4T+1)],color="black",linewidth=3)
plt.plot(np.arange(0,l3T),[l3T-0.5 for xx in range(0,l3T)],color="black",linewidth=1)
plt.plot([l3T-0.5 for xx in range(0,l3T+1)],np.arange(0,l3T+1),color="black",linewidth=1)

plt.vlines(x=l1T,linestyle="-",ymin=0,ymax=l1T,color=yj_color2['1'],linewidth=5)#添加垂直直线,#线起始位置
plt.vlines(x=l1T,linestyle="-",ymin=l1T,ymax=l2T,color=yj_color2['2'],linewidth=5)#添加垂直直线,#线起始位置
plt.vlines(x=l2T,linestyle="-",ymin=l1T,ymax=l2T,color=yj_color2['2'],linewidth=5)#添加垂直直线
plt.vlines(x=l2T,linestyle="-",ymin=l2T,ymax=l3T,color=yj_color2['3'],linewidth=5)#添加垂直直线
# plt.vlines(x=l3T,linestyle="-",ymin=l2T,ymax=l3T,color=yj_color['3'],linewidth=5)#添加垂直直线
# plt.vlines(x=l3T,linestyle="-",ymin=l3T,ymax=l4T,color=yj_color['4'],linewidth=5)#添加垂直直线

plt.plot(np.arange(0,l1T+1),[l1T for xx in range(l1T+1)],color=yj_color2['1'],linewidth=5)###1
plt.plot(np.arange(l1T,l2T+1),[l1T for xx in range(l1T,l2T+1)],color=yj_color2['2'],linewidth=5)
plt.plot(np.arange(l1T,l2T+1),[l2T for xx in range(l1T,l2T+1)],color=yj_color2['2'],linewidth=5)###3
plt.plot(np.arange(l2T,l3T+1),[l2T for xx in range(l2T,l3T+1)],color=yj_color2['3'],linewidth=5)###2
# plt.plot(np.arange(l2T,l3T+1),[l3T for xx in range(l2T,l3T+1)],color=yj_color['3'],linewidth=5)###4
# plt.plot(np.arange(l3T,l4T+1),[l3T for xx in range(l3T,l4T+1)],color=yj_color['4'],linewidth=5)

# plt.plot(np.arange(0,l3T+1),[l3T-0.5 for xx in range(0,l3T+1)],color="black",linewidth=1)
# plt.plot([l3-12 for xx in range(0,l3T+1)],np.arange(0,l3T+1),color="black",linewidth=1)
# plt.axhline(y=l1,xmin=1,xmax=3,color="black",linestyle='-')#线型
# plt.savefig('C:\\Users\\lu\\Desktop\\标度律\\4_retuTimes.png')#保存图片
# plt.tight_layout()
plt.savefig('E:/文档系列/python 系列/picScalling/20201025NEW/map/Fig3_e_times3.pdf', bbox_inches='tight')

# %%
#### 得到GDP 的热图################

# %%
###2.3
ptd_G=(1-dfGDP)/2
np.set_printoptions(precision=5, suppress=True)  # suppress scientific float notation
Z11_G = linkage(ptd_G, 'ward')
end = 20
last_G = Z11_G[0:, 2]#Z的第三列
last_rev_G = last[::-1]#Z倒过来读
idxs_G = np.arange(1, len(last_G) + 1)
plt.plot(idxs_G[:end], last_rev_G[:end])

# %%
###2.3
from scipy.cluster.hierarchy import fcluster
#max_d = 10#切割线
#clusters1 = fcluster(Z11, max_d, criterion='distance')
#1:北京市2：上海市4:广东省深圳市,广东省珠海市,浙江省杭州市,江苏省苏州市
clusters_G = fcluster(Z11_G,4, criterion='maxclust')
plt.hist(clusters_G,bins=4)
#clusters2_1
# Out:
# (array([75., 52.,  7., 15.]),
#  array([1.  , 1.75, 2.5 , 3.25, 4.  ]),
#  <a list of 4 Patch objects>)

# %%
dfCijG=dfGDP
dfCijG['cluster']=clusters_G
clusterG=sorted(dfCijG['cluster'].drop_duplicates().values)
aG=list(sns.color_palette("hls", len(clusterG)))
yj_colorG=dict(zip(clusterG,aG)) ####将颜色和类别匹配
DATAG=[]###按照城市对数据进行分组
sG=[]
for li in clusterG:
    dat=dfCijG[dfCijG['cluster'].isin([li])]
    DATAG.append(dat)
    sG.append(dat.shape[0])

# %%
dataG1=DATAG[0].append(DATAG[1])
dataG2=DATAG[2].append(DATAG[3])
# dataM3=dataM2.append(DATA[4])
dataG=dataG1.append(dataG2)
dataG_2 = dataG.drop(['cluster'], axis=1)##去除cluster列数据

# %%
### 按照列对相关性数据进行排序，先将dataframe转置，再按照行进行排序即可
dataG_3 = dataG_2.T ###转置
dataG_3['cluster']=clusters_G
# clusterm=dfCijM['cluster'].drop_duplicates().values
DATA_col_G = []###按照城市对数据进行分组
s_col_G = []
for li in clusterG:
    dat_col_G = dataG_3[dataG_3['cluster'].isin([li])]
    DATA_col_G.append(dat_col_G)
    s_col_G.append(dat_col_G.shape[0])
    
### 按照得到的分类数据进行排序
dataN1_col_G=DATA_col_G[0].append(DATA_col_G[1])
dataN2_col_G=DATA_col_G[2].append(DATA_col_G[3])
# dataN3_col_M=dataN2_col_M.append(DATA_col_M[4])
dataN_col_G=dataN1_col_G.append(dataN2_col_G)

# %%
### 画出热图 
# Dff=dff[dff<0.1]
# DFF= Dff[dff>0.016]
# DFF2=np.log10(DFF)
##### 得到先惯性的热图 ##########
DFF2G = dataN_col_G.drop(['cluster'], axis=1) ###将cluster列删除
# l1=len(dataA1)
# l2=l1+len(dataA2)
# l3=l2+len(dataA3)
# l4=l3+len(dataA4)
# l5=l4+len(dataA5)
l1G = s_col_G[0]
l2G = s_col_G[1]+l1G
l3G = s_col_G[2]+l2G
l4G = s_col_G[3]+l3G
l5G = s_col_G[3]

f,ax1G = plt.subplots(figsize = (10.5,7))
cmap = plt.cm.get_cmap('seismic')
sns.heatmap(DFF2G, linewidths = 0.05, ax = ax1G, vmax=max(DFF2G.max().values), vmin=min(DFF2G.min().values), xticklabels=False, yticklabels=False, cmap=cmap)
plt.vlines(x=l1G,linestyle="-",ymin=0,ymax=l1G,color=yj_color['1'],linewidth=5)#添加垂直直线,#线起始位置
plt.vlines(x=l1G,linestyle="-",ymin=l1G,ymax=l2G,color=yj_color['2'],linewidth=5)#添加垂直直线,#线起始位置
plt.vlines(x=l2G,linestyle="-",ymin=l1G,ymax=l2G,color=yj_color['2'],linewidth=5)#添加垂直直线
plt.vlines(x=l2G,linestyle="-",ymin=l2G,ymax=l3G,color=yj_color['3'],linewidth=5)#添加垂直直线
plt.vlines(x=l3G,linestyle="-",ymin=l2G,ymax=l3G,color=yj_color['3'],linewidth=5)#添加垂直直线
plt.vlines(x=l3G,linestyle="-",ymin=l3G,ymax=l4G,color=yj_color['4'],linewidth=5)#添加垂直直线

plt.plot(np.arange(0,l1G+1),[l1G for xx in range(l1G+1)],color=yj_color['1'],linewidth=5)###1
plt.plot(np.arange(l1G,l2G+1),[l1G for xx in range(l1G,l2G+1)],color=yj_color['2'],linewidth=5)
plt.plot(np.arange(l1G,l2G+1),[l2G for xx in range(l1G,l2G+1)],color=yj_color['2'],linewidth=5)###3
plt.plot(np.arange(l2G,l3G+1),[l2G for xx in range(l2G,l3G+1)],color=yj_color['3'],linewidth=5)###2
plt.plot(np.arange(l2G,l3G+1),[l3G for xx in range(l2G,l3G+1)],color=yj_color['3'],linewidth=5)###4
plt.plot(np.arange(l3G,l4G+1),[l3G for xx in range(l3G,l4G+1)],color=yj_color['4'],linewidth=5)

plt.axvline(x=0,linestyle="-",color="black",linewidth=1)#添加垂直直线
plt.axhline(y=0,linestyle="-",color="black",linewidth=1)#添加垂直直线
plt.axvline(x=l4G,linestyle="-",color="black",linewidth=1)#添加垂直直线
plt.axhline(y=l4G,linestyle="-",color="black",linewidth=1)#添加垂直直线
plt.plot(np.arange(0,l4G+1),[l4G-0.5 for xx in range(0,l4G+1)],color="black",linewidth=1)
plt.plot([l4G-0.5 for xx in range(0,l4G+1)],np.arange(0,l4G+1),color="black",linewidth=1)
# plt.plot(np.arange(0,l4+1),[126.8 for xx in range(0,l4+1)],color="black",linewidth=1)
# plt.axhline(y=l1,xmin=1,xmax=3,color="black",linestyle='-')#线型
# plt.savefig('C:\\Users\\lu\\Desktop\\标度律\\4_retuGDP.png')#保存图片
# plt.tight_layout()
plt.savefig('E:/文档系列/python 系列/picScalling/20201025NEW/Fig3_f_GDP.pdf', bbox_inches='tight')

# %%
####### 将经纬度和城市匹配####
dataJW = pd.read_excel('E:/文档系列/python 系列/TheData/total/城市经纬度（baidu）.xlsx')
JD = dataJW.set_index("City").to_dict()['Longitude']###得到2017年的city-gdp、pop、area、roadlength
WD = dataJW.set_index("City").to_dict()['Latitude']
def d1(s):
    end=JD[s]
    return(end)
def d2(s):
    end=WD[s]
    return(end)

# %%
###将分类结果保存在excel中
dataCijclster = pd.DataFrame()
dataCijclster['city'] = cityM
dataCijclster['clusterM'] = clusters_M
dataCijclster['clusterT'] = clusters_T
dataCijclster['clusterG'] = clusters_G
dataCijclster['Longitude']=dataCijclster['city'].map(d1)###总表中的城市与其对应
dataCijclster['Latitude']=dataCijclster['city'].map(d2)
dataCijclster.to_excel('E:/文档系列/python 系列/TheData/0_theDATA_end(1991-2017pop&GDP&vc)/CijClass(2000-2017).xlsx')

# %%
len(cityM),len(clusters_G),len(clusters_T)
# Out:
# (149, 149, 149)

# %%
####### 将所有的都分为 3 类###

# %%
###### amount ########3
###2.3
from scipy.cluster.hierarchy import fcluster
#max_d = 10#切割线
#clusters1 = fcluster(Z11, max_d, criterion='distance')
#1:北京市2：上海市4:广东省深圳市,广东省珠海市,浙江省杭州市,江苏省苏州市
clusters_M3 = fcluster(Z11,3, criterion='maxclust')
plt.hist(clusters_M3,bins=3)
#clusters2_1
# Out:
# (array([68., 40., 41.]),
#  array([1.     , 1.66667, 2.33333, 3.     ]),
#  <a list of 3 Patch objects>)

# %%
cludfM3=pd.DataFrame()###保存城市和分类在dataframe,并将每一类分类对应不同颜色

dfCijM3=dfAmount
dfCijM3['cluster']=clusters_M3
clusterm3=sorted(dfCijM3['cluster'].drop_duplicates().values)
DATA3=[]###按照城市对数据进行分组
s3=[]
for li3 in clusterm3:
    dat3=dfCijM3[dfCijM3['cluster'].isin([li3])]
    DATA3.append(dat3)
    s3.append(dat3.shape[0])
    
dataM13=DATA3[0].append(DATA3[1])
dataM3=dataM13.append(DATA3[2])
dataM_23 = dataM3.drop(['cluster'], axis=1)##去除cluster列数据

### 按照列对相关性数据进行排序，先将dataframe转置，再按照行进行排序即可
dataM_33 = dataM_23.T ###转置
dataM_33['cluster']=clusters_M3
# clusterm=dfCijM['cluster'].drop_duplicates().values
DATA_col_M3 = []###按照城市对数据进行分组
s_col_M3 = []
for li in clusterm3:
    dat_col_M3 = dataM_33[dataM_33['cluster'].isin([li])]
    DATA_col_M3.append(dat_col_M3)
    s_col_M3.append(dat_col_M3.shape[0])
    
### 按照得到的分类数据进行排序
dataN1_col_M3=DATA_col_M3[0].append(DATA_col_M3[1])
dataN_col_M3=dataN1_col_M3.append(DATA_col_M3[2])

# %%
### 画出热图 
# Dff=dff[dff<0.1]
# DFF= Dff[dff>0.016]
# DFF2=np.log10(DFF)
##### 得到先惯性的热图 ##########
DFF23 = dataN_col_M3.drop(['cluster'], axis=1) ###将cluster列删除
# l1=len(dataA1)
# l2=l1+len(dataA2)
# l3=l2+len(dataA3)
# l4=l3+len(dataA4)
# l5=l4+len(dataA5)
l1 = s_col_M3[0]
l2 = s_col_M3[1]+l1
l3 = s_col_M3[2]+l2


f,ax1M3 = plt.subplots(figsize = (8,7))
cmap = plt.cm.get_cmap('seismic')
sns.heatmap(DFF23, linewidths = 0.05, ax = ax1M3, vmax=max(DFF23.max().values), vmin=min(DFF23.min().values), xticklabels=False, yticklabels=False, cmap=cmap,cbar =False)
# plt.axhline(y=l1,linestyle="-",color="black")#添加垂直直线
plt.axvline(x=0,linestyle="-",color="black",linewidth=1)#添加垂直直线
plt.axhline(y=0,linestyle="-",color="black",linewidth=1)#添加垂直直线
plt.vlines(x=l1,linestyle="-",ymin=0,ymax=l1,color=yj_color['1'],linewidth=5)#添加垂直直线,#线起始位置
plt.vlines(x=l1,linestyle="-",ymin=l1,ymax=l2,color=yj_color['2'],linewidth=5)#添加垂直直线,#线起始位置
# plt.axvline(x=l4,linestyle="-",color="black",linewidth=1)#添加垂直直线
# plt.axhline(y=l4,linestyle="-",color="black",linewidth=1)#添加垂直直线
# plt.axhline(y=l2,linestyle="-",color="black")#添加垂直直线
plt.vlines(x=l2,linestyle="-",ymin=l1,ymax=l2,color=yj_color['2'],linewidth=5)#添加垂直直线
plt.vlines(x=l2,linestyle="-",ymin=l2,ymax=l3,color=yj_color['3'],linewidth=5)#添加垂直直线
plt.vlines(x=l3,linestyle="-",ymin=l2,ymax=l3,color=yj_color['3'],linewidth=5)#添加垂直直线

plt.plot(np.arange(0,l1+1),[l1 for xx in range(l1+1)],color=yj_color['1'],linewidth=5)###1
plt.plot(np.arange(l1,l2+1),[l1 for xx in range(l1,l2+1)],color=yj_color['2'],linewidth=5)
plt.plot(np.arange(l1,l2+1),[l2 for xx in range(l1,l2+1)],color=yj_color['2'],linewidth=5)###3
plt.plot(np.arange(l2,l3+1),[l2 for xx in range(l2,l3+1)],color=yj_color['3'],linewidth=5)###2
plt.plot(np.arange(l2,l3+1),[l3 for xx in range(l2,l3+1)],color=yj_color['3'],linewidth=5)###4

plt.plot(np.arange(0,l3),[l3-0.5 for xx in range(l3)],color="black",linewidth=1)
plt.plot([l3-0.3 for xx in range(l3)],np.arange(0,l3),color="black",linewidth=1)


# plt.axhline(y=l1,xmin=1,xmax=3,color="black",linestyle='-')#线型
# plt.savefig('C:\\Users\\lu\\Desktop\\标度律\\4_retu.png')#保存图片
# plt.tight_layout()
plt.savefig('E:/文档系列/python 系列/picScalling/20201025NEW/map/Fig3_d_amount3.pdf', bbox_inches='tight')

# %%
#######3 GDP#######3

# %%
clusters_G3 = fcluster(Z11_G,3, criterion='maxclust')
plt.hist(clusters_G3,bins=3)
# Out:
# (array([75., 52., 22.]),
#  array([1.     , 1.66667, 2.33333, 3.     ]),
#  <a list of 3 Patch objects>)

# %%
dfCijG3=dfGDP
dfCijG3['cluster']=clusters_G3
clusterG3=sorted(dfCijG3['cluster'].drop_duplicates().values)

DATAG3=[]###按照城市对数据进行分组
sG3=[]
for li in clusterG3:
    dat3=dfCijG3[dfCijG3['cluster'].isin([li])]
    DATAG3.append(dat3)
    sG3.append(dat3.shape[0])
    
dataG13=DATAG3[0].append(DATAG3[1])
dataG3=dataG13.append(DATAG3[2])
dataG_23 = dataG3.drop(['cluster'], axis=1)##去除cluster列数据

### 按照列对相关性数据进行排序，先将dataframe转置，再按照行进行排序即可
dataG_33 = dataG_23.T ###转置
dataG_33['cluster']=clusters_G3
# clusterm=dfCijM['cluster'].drop_duplicates().values
DATA_col_G3 = []###按照城市对数据进行分组
s_col_G3 = []
for li in clusterG3:
    dat_col_G3 = dataG_33[dataG_33['cluster'].isin([li])]
    DATA_col_G3.append(dat_col_G3)
    s_col_G3.append(dat_col_G3.shape[0])
    
### 按照得到的分类数据进行排序
dataN1_col_G3=DATA_col_G3[0].append(DATA_col_G3[1])
dataN_col_G3=dataN1_col_G3.append(DATA_col_G3[2])

# %%
DATAG3[1].shape[0]
# Out:
# 52

# %%
### 画出热图 
# Dff=dff[dff<0.1]
# DFF= Dff[dff>0.016]
# DFF2=np.log10(DFF)
##### 得到先惯性的热图 ##########
DFF2G3 = dataN_col_G3.drop(['cluster'], axis=1) ###将cluster列删除
# l1=len(dataA1)
# l2=l1+len(dataA2)
# l3=l2+len(dataA3)
# l4=l3+len(dataA4)
# l5=l4+len(dataA5)
l1G = s_col_G3[0]
l2G = s_col_G3[1]+l1G
l3G = s_col_G3[2]+l2G

f,ax1G3 = plt.subplots(figsize = (10.5,7))
cmap = plt.cm.get_cmap('seismic')
sns.heatmap(DFF2G3, linewidths = 0.05, ax = ax1G3, vmax=max(DFF2G3.max().values), vmin=min(DFF2G3.min().values), xticklabels=False, yticklabels=False, cmap=cmap)
plt.vlines(x=l1G,linestyle="-",ymin=0,ymax=l1G,color=yj_color['1'],linewidth=5)#添加垂直直线,#线起始位置
plt.vlines(x=l1G,linestyle="-",ymin=l1G,ymax=l2G,color=yj_color['2'],linewidth=5)#添加垂直直线,#线起始位置
plt.vlines(x=l2G,linestyle="-",ymin=l1G,ymax=l2G,color=yj_color['2'],linewidth=5)#添加垂直直线
plt.vlines(x=l2G,linestyle="-",ymin=l2G,ymax=l3G,color=yj_color['3'],linewidth=5)#添加垂直直线
plt.vlines(x=l3G,linestyle="-",ymin=l2G,ymax=l3G,color=yj_color['3'],linewidth=5)#添加垂直直线
# plt.vlines(x=l3G,linestyle="-",ymin=l3G,ymax=l4G,color=yj_color['4'],linewidth=5)#添加垂直直线

plt.plot(np.arange(0,l1G+1),[l1G for xx in range(l1G+1)],color=yj_color['1'],linewidth=5)###1
plt.plot(np.arange(l1G,l2G+1),[l1G for xx in range(l1G,l2G+1)],color=yj_color['2'],linewidth=5)
plt.plot(np.arange(l1G,l2G+1),[l2G for xx in range(l1G,l2G+1)],color=yj_color['2'],linewidth=5)###3
plt.plot(np.arange(l2G,l3G+1),[l2G for xx in range(l2G,l3G+1)],color=yj_color['3'],linewidth=5)###2
plt.plot(np.arange(l2G,l3G+1),[l3G for xx in range(l2G,l3G+1)],color=yj_color['3'],linewidth=5)###4
# plt.plot(np.arange(l3G,l4G+1),[l3G for xx in range(l3G,l4G+1)],color=yj_color['4'],linewidth=5)

plt.axvline(x=0,linestyle="-",color="black",linewidth=1)#添加垂直直线
plt.axhline(y=0,linestyle="-",color="black",linewidth=1)#添加垂直直线
plt.axvline(x=l3G,linestyle="-",color="black",linewidth=1)#添加垂直直线
plt.axhline(y=l3G,linestyle="-",color="black",linewidth=1)#添加垂直直线
plt.plot(np.arange(0,l3G+1),[l3G-0.5 for xx in range(0,l3G+1)],color="black",linewidth=1)
plt.plot([l3G-0.5 for xx in range(0,l3G+1)],np.arange(0,l3G+1),color="black",linewidth=1)
# plt.plot(np.arange(0,l4+1),[126.8 for xx in range(0,l4+1)],color="black",linewidth=1)
# plt.axhline(y=l1,xmin=1,xmax=3,color="black",linestyle='-')#线型
# plt.savefig('C:\\Users\\lu\\Desktop\\标度律\\4_retuGDP.png')#保存图片
# plt.tight_layout()
plt.savefig('E:/文档系列/python 系列/picScalling/20201025NEW/map/Fig3_f_GDP3.pdf', bbox_inches='tight')

# %%
##### 加入times分为三组的分类
dataCijclster=pd.read_excel('E:/文档系列/python 系列/TheData/0_theDATA_end(1991-2017pop&GDP&vc)/CijClass(2000-2017).xlsx')
dataCijclster['clusterA3'] = clusters_M3
dataCijclster['clusterT3'] = clusters_T2
dataCijclster['clusterG3'] = clusters_G3
dataCijclster.to_excel('E:/文档系列/python 系列/TheData/0_theDATA_end(1991-2017pop&GDP&vc)/CijClass(2000-2017).xlsx')
